# %%
import sys
sys.path.append("..")

#test
from src.data_utils import load_ohlcv

# %%
load_ohlcv("../data/processed/ohlcv.parquet")
#Works
# Out:
#            date ticker        open        high         low       close  \
# 0    2020-01-02   INTC   60.240002   60.970001   60.220001   60.840000
# 1    2020-01-03   INTC   59.810001   60.700001   59.810001   60.099998
# 2    2020-01-06   INTC   59.590000   60.200001   59.330002   59.930000
# 3    2020-01-07   INTC   59.779999   59.799999   58.889999   58.930000
# 4    2020-01-08   INTC   58.889999   59.320000   58.520000   58.970001
# ...         ...    ...         ...         ...         ...         ...
# 3009 2025-12-23   META  660.049988  666.000000  658.250000  664.940002
# 3010 2025-12-24   META  662.530029  668.179993  662.200012  667.549988
# 3011 2025-12-26   META  668.059998  668.950012  661.320007  663.289978
# 3012 2025-12-29   META  658.010010  660.250000  654.390015  658.690002
# 3013 2025-12-30   META  658.690002  672.219971  657.840027  665.950012
#
#       adjusted_close    volume
# 0          53.666473  18056000
# 1          53.013718  15293900
# ...
